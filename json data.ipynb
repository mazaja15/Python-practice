# %%
import json
from pprint import pprint #  to mke it a pretty print so nicer to read

# %%
#  loading and reading a jsonfile with a pretty print
with open (r'C:\Data\CCTV.geojson') as g:
    d = json.load(g) #  this loads the file as a dictionary - always use 
    pprint(d)
# Out:
# {u'features': [{u'geometry': {u'coordinates': [-1.0827585666465949,
#                                                53.959682652190914],
#                               u'type': u'Point'},
#                 u'properties': {u'ADDRESS_1': u'Davygate',
#                                 u'ADDRESS_2': None,
#                                 u'ADDRESS_3': None,
#                                 u'KNOWN_AS': None,
#                                 u'OBJECTID': 330,
#                                 u'POST_CODE': None,
#                                 u'SITE_ID': u'YK1010',
#                                 u'X': 460281.4645,
#                                 u'Y': 451899.9827},
#                 u'type': u'Feature'},
#                {u'geometry': {u'coordinates': [-1.0740199281097855,
#                                                53.96151557743039],
#                               u'type': u'Point'},
#                 u'properties': {u'ADDRESS_1': u'Foss Islands Road',
# ...

# %%
json.dump
