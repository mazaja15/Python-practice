# %%
import pickle

# %%
#  loading data from a pickle 
with open(r'C:\Data\tweets', 'rb') as h:  #  rb - read binary
    londontweets = pickle.load(h)

# %%
londontweets
# Out:
# {u'search_metadata': {u'completed_in': 0.075,
#   u'count': 15,
#   u'max_id': 854353341706620928L,
#   u'max_id_str': u'854353341706620928',
#   u'next_results': u'?max_id=854353333179617279&q=london&include_entities=1',
#   u'query': u'london',
#   u'refresh_url': u'?since_id=854353341706620928&q=london&include_entities=1',
#   u'since_id': 0,
#   u'since_id_str': u'0'},
#  u'statuses': [{u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Tue Apr 18 15:18:04 +0000 2017',
#    u'entities': {u'hashtags': [],
#     u'media': [{u'display_url': u'pic.twitter.com/ayVXxanL3m',
#       u'expanded_url': u'https://twitter.com/HSupdating/status/854324214937128960/video/1',
#       u'id': 854324154627219457L,
#       u'id_str': u'854324154627219457',
#       u'indices': [91, 114],
#       u'media_url': u'http://pbs.twimg.com/ext_tw_video_thumb/854324154627219457/pu/img/7CeHp59L8-jUNKcq.jpg',
# ...
